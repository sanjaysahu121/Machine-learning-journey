# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('us_perm_visas.csv')
df
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 0                              NaN          NaN
# 1                              NaN          NaN
# 2                              NaN          NaN
# 3                              NaN          NaN
# 4                              NaN          NaN
# ...                            ...          ...
# 374357                         NaN   Buena Park
# 374358                         NaN      Seattle
# 374359                         NaN   Schaumburg
# 374360                         NaN  LOS ANGELES
# 374361                         NaN      Phoenix
#
#                                           agent_firm_name agent_state  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# 4                                                     NaN         NaN
# ...                                                   ...         ...
# 374357                           Law Offices of Yohan Lee          CA
# 374358                         MacDonald Hoague & Bayless          WA
# 374359  International Legal and Business Services Grou...          IL
# 374360                        LAW OFFICES OF JAMES S HONG          CA
# 374361            Fragomen, Del Rey, Bernsen & Loewy, LLP          AZ
#
#        application_type        case_no    case_number case_received_date  \
# 0                  PERM  A-07323-97014            NaN                NaN
# 1                  PERM  A-07332-99439            NaN                NaN
# 2                  PERM  A-07333-99643            NaN                NaN
# 3                  PERM  A-07339-01930            NaN                NaN
# 4                  PERM  A-07345-03565            NaN                NaN
# ...                 ...            ...            ...                ...
# 374357              NaN            NaN  A-16363-85407         2016-12-29
# 374358              NaN            NaN  A-16271-56745         2016-12-30
# 374359              NaN            NaN  A-16354-82345         2016-12-30
# 374360              NaN            NaN  A-16357-84250         2016-12-30
# 374361              NaN            NaN  A-16279-59292         2016-12-30
#
#        case_status class_of_admission  ... ri_pvt_employment_firm_to  \
# 0        Certified                J-1  ...                       NaN
# 1           Denied                B-2  ...                       NaN
# 2        Certified               H-1B  ...                       NaN
# 3        Certified                B-2  ...                       NaN
# 4        Certified                L-1  ...                       NaN
# ...            ...                ...  ...                       ...
# 374357   Withdrawn                NaN  ...                       NaN
# 374358   Withdrawn                L-1  ...                       NaN
# 374359   Withdrawn               H-1B  ...                       NaN
# 374360   Withdrawn                B-2  ...                       NaN
# 374361   Withdrawn               H-1B  ...                       NaN
#
#        ri_us_workers_considered schd_a_sheepherder     us_economic_sector  \
# 0                           NaN                NaN                     IT
# 1                           NaN                NaN  Other Economic Sector
# 2                           NaN                NaN              Aerospace
# 3                           NaN                NaN  Other Economic Sector
# 4                           NaN                NaN           Advanced Mfg
# ...                         ...                ...                    ...
# 374357                      NaN                  N                    NaN
# 374358                        Y                  N                    NaN
# 374359                      NaN                  N                    NaN
# 374360                      NaN                  N                    NaN
# 374361                      NaN                  N                    NaN
#
#        wage_offer_from_9089 wage_offer_to_9089 wage_offer_unit_of_pay_9089  \
# 0                   75629.0                NaN                          yr
# 1                   37024.0                NaN                          yr
# 2                   47923.0                NaN                          yr
# 3                     10.97                NaN                          hr
# 4                  100000.0                NaN                          yr
# ...                     ...                ...                         ...
# 374357            28,330.00                NaN                        Year
# 374358           122,000.00         142,000.00                        Year
# 374359            79,082.00          79,082.00                        Year
# 374360            37,981.00                NaN                        Year
# 374361            84,926.00         121,500.00                        Year
#
#        wage_offered_from_9089 wage_offered_to_9089  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
# ...                       ...                  ...
# 374357                    NaN                  NaN
# 374358                    NaN                  NaN
# 374359                    NaN                  NaN
# 374360                    NaN                  NaN
# 374361                    NaN                  NaN
#
#         wage_offered_unit_of_pay_9089
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 374357                            NaN
# 374358                            NaN
# 374359                            NaN
# 374360                            NaN
# 374361                            NaN
#
# [374362 rows x 154 columns]

# %%
df.shape
# Out:
# (374362, 154)

# %%
df.head()
# Out:
#   add_these_pw_job_title_9089 agent_city agent_firm_name agent_state  \
# 0                         NaN        NaN             NaN         NaN
# 1                         NaN        NaN             NaN         NaN
# 2                         NaN        NaN             NaN         NaN
# 3                         NaN        NaN             NaN         NaN
# 4                         NaN        NaN             NaN         NaN
#
#   application_type        case_no case_number case_received_date case_status  \
# 0             PERM  A-07323-97014         NaN                NaN   Certified
# 1             PERM  A-07332-99439         NaN                NaN      Denied
# 2             PERM  A-07333-99643         NaN                NaN   Certified
# 3             PERM  A-07339-01930         NaN                NaN   Certified
# 4             PERM  A-07345-03565         NaN                NaN   Certified
#
#   class_of_admission  ... ri_pvt_employment_firm_to ri_us_workers_considered  \
# 0                J-1  ...                       NaN                      NaN
# 1                B-2  ...                       NaN                      NaN
# 2               H-1B  ...                       NaN                      NaN
# 3                B-2  ...                       NaN                      NaN
# 4                L-1  ...                       NaN                      NaN
#
#   schd_a_sheepherder     us_economic_sector wage_offer_from_9089  \
# 0                NaN                     IT              75629.0
# 1                NaN  Other Economic Sector              37024.0
# 2                NaN              Aerospace              47923.0
# 3                NaN  Other Economic Sector                10.97
# 4                NaN           Advanced Mfg             100000.0
#
#   wage_offer_to_9089 wage_offer_unit_of_pay_9089 wage_offered_from_9089  \
# 0                NaN                          yr                    NaN
# 1                NaN                          yr                    NaN
# 2                NaN                          yr                    NaN
# 3                NaN                          hr                    NaN
# 4                NaN                          yr                    NaN
#
#   wage_offered_to_9089  wage_offered_unit_of_pay_9089
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
#
# [5 rows x 154 columns]

# %%
df.sample()
# Out:
#        add_these_pw_job_title_9089     agent_city  agent_firm_name  \
# 312445                         NaN  Lawrenceville  US MANTECH INC.
#
#        agent_state application_type case_no    case_number case_received_date  \
# 312445          GA              NaN     NaN  A-16088-90012         2016-03-28
#
#        case_status class_of_admission  ... ri_pvt_employment_firm_to  \
# 312445   Certified                F-2  ...                       NaN
#
#        ri_us_workers_considered schd_a_sheepherder us_economic_sector  \
# 312445                      NaN                  N                NaN
#
#        wage_offer_from_9089 wage_offer_to_9089 wage_offer_unit_of_pay_9089  \
# 312445                 9.35                NaN                        Hour
#
#        wage_offered_from_9089 wage_offered_to_9089  \
# 312445                    NaN                  NaN
#
#         wage_offered_unit_of_pay_9089
# 312445                            NaN
#
# [1 rows x 154 columns]

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=154)

# %%
df['case_no']
# Out:
# 0         A-07323-97014
# 1         A-07332-99439
# 2         A-07333-99643
# 3         A-07339-01930
# 4         A-07345-03565
#               ...
# 374357              NaN
# 374358              NaN
# 374359              NaN
# 374360              NaN
# 374361              NaN
# Name: case_no, Length: 374362, dtype: object

# %%
df['case_number']
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#               ...
# 374357    A-16363-85407
# 374358    A-16271-56745
# 374359    A-16354-82345
# 374360    A-16357-84250
# 374361    A-16279-59292
# Name: case_number, Length: 374362, dtype: object

# %% [markdown]
# ##### seeing the values of case_no and case_number it seems both have some meaning , i.e visa application
# ##### few values at the top in case_no is null
# ##### few values at the tail in case_number is null

# %%
df['case_no'].nunique()
# Out:
# 134990

# %%
df['case_number'].nunique() # Top are having null value
# Out:
# 238418

# %%
df['case_number'].isna().sum()
# Out:
# 135269

# %%
#### null vale in case number is almost close to value in case no

# %%
134990+238418
# Out:
# 373408

# %%
casenoindex = df.columns.get_loc('case_no')  # to get column index of case_number
casenumberindex = df.columns.get_loc('case_number')# to get column index of case_number

casenumberlist = []
for value in df.iloc[0:135269 , casenoindex]:
    casenumberlist.append(value)

for value in df.iloc[135269:374362, casenumberindex]:
    casenumberlist.append(value)

# %%
df['casenumber'] = casenumberlist

# %%
df.drop(['case_no','case_number'],axis = 1  , inplace = True)

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_received_date', 'case_status',
#        'class_of_admission', 'country_of_citizenship', 'country_of_citzenship',
#        ...
#        'ri_us_workers_considered', 'schd_a_sheepherder', 'us_economic_sector',
#        'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089', 'casenumber'],
#       dtype='object', length=153)

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'Certified-Expired', 'Withdrawn'],
#       dtype=object)

# %%
for value in df.case_status.unique():
    print(len(df[df['case_status'] == value]) , "occurence of stats'{}'".format(value))
# Out:
# 181933 occurence of stats'Certified'
# 25649 occurence of stats'Denied'
# 148586 occurence of stats'Certified-Expired'
# 18194 occurence of stats'Withdrawn'

# %%
df.case_status.value_counts()
# Out:
# case_status
# Certified            181933
# Certified-Expired    148586
# Denied                25649
# Withdrawn             18194
# Name: count, dtype: int64

# %%
df=df[df.case_status != 'Withdrawn']

# %%
df.case_status.value_counts()
# Out:
# case_status
# Certified            181933
# Certified-Expired    148586
# Denied                25649
# Name: count, dtype: int64

# %%
df.loc[df.case_status == 'Certified-Expired' , 'case_status'] = 'Certified'

# %%
df.case_status.value_counts()
# Out:
# case_status
# Certified    330519
# Denied        25649
# Name: count, dtype: int64

# %%
df.case_status.value_counts(normalize = True)*100
# Out:
# case_status
# Certified    92.798623
# Denied        7.201377
# Name: proportion, dtype: float64

# %% [markdown]
# #### Insight-> 7.2% of the visa application were denied

# %%
df.isnull().sum()
# Out:
# add_these_pw_job_title_9089      317031
# agent_city                       153452
# agent_firm_name                  157646
# agent_state                      156544
# application_type                 229320
#                                   ...
# wage_offer_unit_of_pay_9089      108769
# wage_offered_from_9089           248582
# wage_offered_to_9089             326852
# wage_offered_unit_of_pay_9089    289470
# casenumber                            0
# Length: 153, dtype: int64

# %%
# Dropping all empty rows and collumn

df.dropna(axis = 1 , how = 'all' , inplace = True)
df.dropna(axis = 0, how = 'all' , inplace = True)

# %%
for columns in df.columns:
    print(f"The missing values for {columns} is {df[columns].isnull().sum()}")
# Out:
# The missing values for add_these_pw_job_title_9089 is 317031
# The missing values for agent_city is 153452
# The missing values for agent_firm_name is 157646
# The missing values for agent_state is 156544
# The missing values for application_type is 229320
# The missing values for case_received_date is 126848
# The missing values for case_status is 0
# The missing values for class_of_admission is 21085
# The missing values for country_of_citizenship is 19272
# The missing values for country_of_citzenship is 336951
# The missing values for decision_date is 0
# The missing values for employer_address_1 is 37
# The missing values for employer_address_2 is 236133
# The missing values for employer_city is 10
# The missing values for employer_country is 126920
# The missing values for employer_decl_info_title is 126886
# The missing values for employer_name is 8
# The missing values for employer_num_employees is 126925
# The missing values for employer_phone is 126883
# The missing values for employer_phone_ext is 333670
# The missing values for employer_postal_code is 33
# The missing values for employer_state is 37
# The missing values for employer_yr_estab is 126982
# The missing values for foreign_worker_info_alt_edu_experience is 271883
# The missing values for foreign_worker_info_birth_country is 271880
# The missing values for foreign_worker_info_city is 126875
# The missing values for foreign_worker_info_education is 143554
# The missing values for foreign_worker_info_education_other is 352421
# The missing values for foreign_worker_info_inst is 143883
# The missing values for foreign_worker_info_major is 144800
# The missing values for foreign_worker_info_postal_code is 274425
# The missing values for foreign_worker_info_rel_occup_exp is 271875
# The missing values for foreign_worker_info_req_experience is 271873
# The missing values for foreign_worker_info_state is 142448
# The missing values for foreign_worker_info_training_comp is 271874
# The missing values for foreign_worker_ownership_interest is 271870
# The missing values for foreign_worker_yr_rel_edu_completed is 276735
# The missing values for fw_info_alt_edu_experience is 211154
# The missing values for fw_info_birth_country is 211166
# The missing values for fw_info_education_other is 350072
# The missing values for fw_info_postal_code is 213280
# The missing values for fw_info_rel_occup_exp is 211157
# The missing values for fw_info_req_experience is 211153
# The missing values for fw_info_training_comp is 211156
# The missing values for fw_info_yr_rel_edu_completed is 223131
# The missing values for fw_ownership_interest is 211154
# The missing values for ji_foreign_worker_live_on_premises is 271871
# The missing values for ji_fw_live_on_premises is 211152
# The missing values for ji_live_in_dom_svc_contract is 353855
# The missing values for ji_live_in_domestic_service is 126858
# The missing values for ji_offered_to_sec_j_foreign_worker is 271871
# The missing values for ji_offered_to_sec_j_fw is 211152
# The missing values for job_info_alt_cmb_ed_oth_yrs is 288242
# The missing values for job_info_alt_combo_ed is 290025
# The missing values for job_info_alt_combo_ed_exp is 126881
# The missing values for job_info_alt_combo_ed_other is 347190
# The missing values for job_info_alt_field is 126880
# The missing values for job_info_alt_field_name is 265907
# The missing values for job_info_alt_occ is 213169
# The missing values for job_info_alt_occ_job_title is 213847
# The missing values for job_info_alt_occ_num_months is 214045
# The missing values for job_info_combo_occupation is 126855
# The missing values for job_info_education is 147649
# The missing values for job_info_education_other is 348724
# The missing values for job_info_experience is 126858
# The missing values for job_info_experience_num_months is 227222
# The missing values for job_info_foreign_ed is 127075
# The missing values for job_info_foreign_lang_req is 126862
# The missing values for job_info_job_req_normal is 126859
# The missing values for job_info_job_title is 126889
# The missing values for job_info_major is 151241
# The missing values for job_info_training is 126861
# The missing values for job_info_training_field is 351877
# The missing values for job_info_training_num_months is 351596
# The missing values for job_info_work_city is 95
# The missing values for job_info_work_postal_code is 126930
# The missing values for job_info_work_state is 96
# The missing values for naics_2007_us_code is 337009
# The missing values for naics_2007_us_title is 337598
# The missing values for naics_code is 272070
# The missing values for naics_title is 272070
# The missing values for naics_us_code is 211467
# The missing values for naics_us_code_2007 is 248921
# The missing values for naics_us_title is 211467
# The missing values for naics_us_title_2007 is 251893
# The missing values for orig_case_no is 355892
# The missing values for orig_file_date is 355904
# The missing values for preparer_info_emp_completed is 126885
# The missing values for preparer_info_title is 154602
# The missing values for pw_amount_9089 is 2203
# The missing values for pw_determ_date is 127160
# The missing values for pw_expire_date is 127239
# The missing values for pw_job_title_908 is 211218
# The missing values for pw_job_title_9089 is 145334
# The missing values for pw_level_9089 is 26585
# The missing values for pw_soc_code is 574
# The missing values for pw_soc_title is 2321
# The missing values for pw_source_name_9089 is 2087
# The missing values for pw_source_name_other_9089 is 340927
# The missing values for pw_track_num is 128696
# The missing values for pw_unit_of_pay_9089 is 1481
# The missing values for rec_info_barg_rep_notified is 271930
# The missing values for recr_info_barg_rep_notified is 211165
# The missing values for recr_info_coll_teach_comp_proc is 349374
# The missing values for recr_info_coll_univ_teacher is 126876
# The missing values for recr_info_employer_rec_payment is 126864
# The missing values for recr_info_first_ad_start is 132806
# The missing values for recr_info_job_fair_from is 354447
# The missing values for recr_info_job_fair_to is 354451
# The missing values for recr_info_on_campus_recr_from is 354403
# The missing values for recr_info_on_campus_recr_to is 354410
# The missing values for recr_info_pro_org_advert_from is 342873
# The missing values for recr_info_pro_org_advert_to is 342879
# The missing values for recr_info_prof_org_advert_from is 328771
# The missing values for recr_info_prof_org_advert_to is 328778
# The missing values for recr_info_professional_occ is 126861
# The missing values for recr_info_radio_tv_ad_from is 336666
# The missing values for recr_info_radio_tv_ad_to is 336665
# The missing values for recr_info_second_ad_start is 132843
# The missing values for recr_info_sunday_newspaper is 132717
# The missing values for recr_info_swa_job_order_end is 132841
# The missing values for recr_info_swa_job_order_start is 132819
# The missing values for refile is 247861
# The missing values for ri_1st_ad_newspaper_name is 132797
# The missing values for ri_2nd_ad_newspaper_name is 132858
# The missing values for ri_2nd_ad_newspaper_or_journal is 132825
# The missing values for ri_campus_placement_from is 327380
# The missing values for ri_campus_placement_to is 327390
# The missing values for ri_coll_tch_basic_process is 349382
# The missing values for ri_coll_teach_pro_jnl is 350625
# The missing values for ri_coll_teach_select_date is 350626
# The missing values for ri_employee_referral_prog_from is 289853
# The missing values for ri_employee_referral_prog_to is 289852
# The missing values for ri_employer_web_post_from is 224277
# The missing values for ri_employer_web_post_to is 224300
# The missing values for ri_job_search_website_from is 166377
# The missing values for ri_job_search_website_to is 166388
# The missing values for ri_layoff_in_past_six_months is 126878
# The missing values for ri_local_ethnic_paper_from is 239853
# The missing values for ri_local_ethnic_paper_to is 239852
# The missing values for ri_posted_notice_at_worksite is 126927
# The missing values for ri_pvt_employment_firm_from is 340050
# The missing values for ri_pvt_employment_firm_to is 340052
# The missing values for ri_us_workers_considered is 339595
# The missing values for schd_a_sheepherder is 126866
# The missing values for us_economic_sector is 235300
# The missing values for wage_offer_from_9089 is 107705
# The missing values for wage_offer_to_9089 is 285397
# The missing values for wage_offer_unit_of_pay_9089 is 108769
# The missing values for wage_offered_from_9089 is 248582
# The missing values for wage_offered_to_9089 is 326852
# The missing values for wage_offered_unit_of_pay_9089 is 289470
# The missing values for casenumber is 0

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_received_date', 'case_status',
#        'class_of_admission', 'country_of_citizenship', 'country_of_citzenship',
#        ...
#        'ri_us_workers_considered', 'schd_a_sheepherder', 'us_economic_sector',
#        'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089', 'wage_offered_from_9089',
#        'wage_offered_to_9089', 'wage_offered_unit_of_pay_9089', 'casenumber'],
#       dtype='object', length=153)

# %%
df['decision_date']
# Out:
# 0         2012-02-01
# 1         2011-12-21
# 2         2011-12-01
# 3         2011-12-01
# 4         2012-01-26
#              ...
# 374349    2016-12-30
# 374350    2016-12-30
# 374351    2016-12-30
# 374352    2016-12-30
# 374353    2016-12-30
# Name: decision_date, Length: 356168, dtype: object

# %%
df['decision_date'] = pd.to_datetime(df['decision_date'])
df['decision_date']
# Out:
# 0        2012-02-01
# 1        2011-12-21
# 2        2011-12-01
# 3        2011-12-01
# 4        2012-01-26
#             ...
# 374349   2016-12-30
# 374350   2016-12-30
# 374351   2016-12-30
# 374352   2016-12-30
# 374353   2016-12-30
# Name: decision_date, Length: 356168, dtype: datetime64[ns]

# %%
df['year'] = df['decision_date'].dt.year
df['month'] = df['decision_date'].dt.month
df['day'] = df['decision_date'].dt.day

# %%
df.drop('decision_date',axis = 1 , inplace = True)

# %%
# year wise status 


sns.countplot(x ='year',hue = 'case_status' , data = df)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# ### insight -> upward trend -> 2016 highest

# %%
df.employer_city.unique()
# Out:
# array(['NEW YORK', 'CARLSTADT', 'GLEN ALLEN', ..., 'austin',
#        'Carson City', 'Northfield'], dtype=object)

# %%
df.employer_city.value_counts()
# Out:
# employer_city
# NEW YORK           15992
# COLLEGE STATION    11983
# SANTA CLARA        10446
# SAN JOSE            9004
# REDMOND             8469
#                    ...
# PARADISE               1
# GRANITE SPRINGS        1
# GALLIANO               1
# BURKBURNETT            1
# Northfield             1
# Name: count, Length: 8324, dtype: int64

# %%
df['employer_city'] = df['employer_city'].str.upper()
df['employer_city'].unique()
# Out:
# array(['NEW YORK', 'CARLSTADT', 'GLEN ALLEN', ..., 'PERRYSVILLE',
#        'STILWELL', 'ROYAL OAKS'], dtype=object)

# %% [markdown]
# #### Employer city year wise which are the city where the visa approved people are working

# %%
sns.countplot(x = 'employer_city',hue = 'year',data= df,order = df.employer_city.value_counts().iloc[:10].index,palette = 'muted')
# Out:
# <Axes: xlabel='employer_city', ylabel='count'>

# %%
fig ,ax  = plt.subplots()
fig.set_size_inches(13.6,8.5)

sns.set_context('paper' ,rc = {"font.size":12,"axes.titlesize":12,"axes.labelsize":12} )
sns.countplot(x = 'employer_city',hue = 'year',data= df,order = df.employer_city.value_counts().iloc[:10].index,palette = 'muted')
plt.xticks(rotation = 90)
ax.set(xlabel = 'Employer city',ylabel = 'Number of visa application')
plt.show()

# %% [markdown]
# ### isnight ->college satation in 2015 has a highest no. of appliocation visa

# %% [markdown]
# #### Top 10 employers by visa application

# %%
top_emp = df['employer_name'].value_counts().head(10)
top_emp
# Out:
# employer_name
# COGNIZANT TECHNOLOGY SOLUTIONS US CORPORATION    11936
# MICROSOFT CORPORATION                             8082
# INTEL CORPORATION                                 6120
# GOOGLE INC.                                       5060
# AMAZON CORPORATE LLC                              3639
# CISCO SYSTEMS, INC.                               2592
# APPLE INC.                                        2536
# ORACLE AMERICA, INC.                              2505
# INFOSYS LTD.                                      2498
# DELOITTE CONSULTING LLP                           1689
# Name: count, dtype: int64

# %%
top_emp = df['employer_name'].value_counts().head(10)
top_emp.plot(kind = 'bar',color = 'skyblue')

for i , v in enumerate(top_emp):
    plt.text(i , v+10, str(v),ha = 'center',va = 'bottom',fontsize = 10)

# %% [markdown]
# ##### Insight - > higest no of application is from COGNIZANT TECHNOLOGY SOLUTIONS US CORPORATION

# %%
df['us_economic_sector'].value_counts()
# Out:
# us_economic_sector
# IT                       49311
# Advanced Mfg             17601
# Other Economic Sector    14662
# Finance                   8686
# Educational Services      8561
# Health Care               6407
# Retail                    4208
# Aerospace                 3917
# Hospitality               1767
# Construction              1315
# Automotive                1084
# Energy                    1021
# Transportation             893
# Agribusiness               784
# Biotechnology              436
# Geospatial                 137
# Homeland Security           78
# Name: count, dtype: int64

# %%
us_economic_counts = {}
for value in df['us_economic_sector'].dropna():
    if value in us_economic_counts:
        us_economic_counts[value] +=1
    else:
        us_economic_counts[value] =1

us_economic_counts
# Out:
# {'IT': 49311,
#  'Other Economic Sector': 14662,
#  'Aerospace': 3917,
#  'Advanced Mfg': 17601,
#  'Educational Services': 8561,
#  'Retail': 4208,
#  'Construction': 1315,
#  'Hospitality': 1767,
#  'Automotive': 1084,
#  'Health Care': 6407,
#  'Agribusiness': 784,
#  'Finance': 8686,
#  'Energy': 1021,
#  'Transportation': 893,
#  'Homeland Security': 78,
#  'Biotechnology': 436,
#  'Geospatial': 137}

# %%
# no as key and name of sector as list

usecollabels = []
usecolvalues = []
for  key ,value in us_economic_counts.items():
    usecollabels.append(key)
    usecolvalues.append(value)

# %%
usecollabels
# Out:
# ['IT',
#  'Other Economic Sector',
#  'Aerospace',
#  'Advanced Mfg',
#  'Educational Services',
#  'Retail',
#  'Construction',
#  'Hospitality',
#  'Automotive',
#  'Health Care',
#  'Agribusiness',
#  'Finance',
#  'Energy',
#  'Transportation',
#  'Homeland Security',
#  'Biotechnology',
#  'Geospatial']

# %%
usecolvalues
# Out:
# [49311,
#  14662,
#  3917,
#  17601,
#  8561,
#  4208,
#  1315,
#  1767,
#  1084,
#  6407,
#  784,
#  8686,
#  1021,
#  893,
#  78,
#  436,
#  137]

# %%
## Pie chart 


plt.figure(figsize = (13,13))
explode = (0.035,0,0,0,0,0,0,0,0,0)
plt.pie(usecolvalues[:10],labels = usecollabels[:10],explode = explode,shadow = True,autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# ### Insgiths -> Maximum no of application for visa is from  IT sector

# %%
df.job_info_job_title.value_counts().head(20)
# Out:
# job_info_job_title
# Software Engineer                   14372
# Computer Systems Analyst - V         4747
# Senior Software Engineer             3801
# Computer Systems Analyst - II        3416
# Software Developer                   2880
# Assistant Professor                  2604
# Programmer Analyst                   2534
# Computer Systems Analyst - IV        2496
# Systems Analyst                      2034
# Software Development Engineer II     1630
# Poultry Processing Worker            1594
# Component Design Engineer            1064
# Poultry Processor                    1037
# Business Analyst                      963
# software engineer                     932
# SOFTWARE ENGINEER                     877
# Senior Programmer Analyst             862
# Sr. Software Engineer                 847
# Senior Software Developer             817
# Commercial Cleaner                    802
# Name: count, dtype: int64

# %%
# Computer Systems Analyst - V ,Computer Systems Analyst - IV  and so on..
# Have different job title but domian are same 

# SOFTWARE ENGINEER , Sr. Software Engineer >> ll of them come in same profile

# %%
# Converting to lower case

df.job_info_job_title = df.job_info_job_title.str.lower()

# %%
# Splitting job title by '-'
df['job_info_job_title'] = df['job_info_job_title'].astype(str).str.split('-').str[0]
# Splitting job title by 'ii'
df['job_info_job_title'] = df['job_info_job_title'].astype(str).str.split('ii').str[0]
# Splitting job title by '/'
df['job_info_job_title'] = df['job_info_job_title'].astype(str).str.split('/').str[0]
# Removing leading and ending spaces 
df['job_info_job_title'] = df['job_info_job_title'].astype(str).str.strip()
# Replacing 'sr.' values with senior 
df['job_info_job_title'] = df['job_info_job_title'].str.replace('sr.' , 'senior')
# Replacing 'NaN' , 'NaT' and 'nan' values with np.nan 
df['job_info_job_title'].replace(['NaN','NaT','nan'],np.nan , inplace = True)


df['job_info_job_title'].value_counts(dropna = True)[:10]
# Out:
# job_info_job_title
# software engineer                18582
# computer systems analyst         12054
# senior software engineer          5802
# software developer                4501
# programmer analyst                3763
# assistant professor               2869
# software development engineer     2766
# systems analyst                   2587
# senior programmer analyst         1884
# senior software developer         1625
# Name: count, dtype: int64

# %%
# Get the top 10 job title by count

top_job_titles=df.job_info_job_title.value_counts().head(10)
# Create a bar plot

plt.figure(figsize = (12,13))
plt.bar(top_job_titles.index , top_job_titles,color = sns.color_palette('viridis',len(top_job_titles)))

# add count labels above the bar 
for i , v in enumerate(top_job_titles):
    plt.text(i , v+10, str(v),ha = 'center',va = 'bottom',fontsize = 10,rotation = 90)

plt.xlabel('Job title')
plt.ylabel('Number of visa application')
plt.title('Top 10 job titles by visa application')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insight -> Software engineer apply most visa application

# %%
# convert country of citizenship to ctegorical data type
pd.Categorical(df.country_of_citizenship)
# Out:
# [NaN, NaN, NaN, NaN, NaN, ..., 'INDIA', 'INDIA', 'INDIA', 'INDIA', 'INDIA']
# Length: 356168
# Categories (201, object): ['AFGHANISTAN', 'ALBANIA', 'ALGERIA', 'ANDORRA', ..., 'YEMEN', 'YUGOSLAVIA', 'ZAMBIA', 'ZIMBABWE']

# %%
fig, ax = plt.subplots(figsize=(12.7, 8.27))
sns.set_context(rc={"font.size":14, "axes.labelsize":12})

# Creating the count plot
sns.countplot(x='country_of_citizenship', hue='case_status', data=df,
              palette=sns.diverging_palette(255, 133, l=60, n=7, center="light"),
              order=df.country_of_citizenship.value_counts().iloc[:7].index)

plt.xticks(rotation=90)

# Setting label titles
ax.set(xlabel='Country of citizenship', ylabel='Number of Visa applications')

plt.show()  # This line is necessary to display the plot

# %%
# Setting plot parameters
plt.figure(figsize=(10.7, 7.27))

# Creating the count plot
sns.countplot(x='application_type', data=df, palette='GnBu_d', order=df['application_type'].value_counts().index[:10])

# Iterating over elements in "application_type" column and displaying counts above bars
for i, v in enumerate(df['application_type'].value_counts().head(10)):
    plt.text(i, v, str(v), ha='center', va='bottom')

# Setting labels
plt.xlabel('Application type')
plt.ylabel('Number of Visa applications')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting plot parameters
fig, ax = plt.subplots()
fig.set_size_inches(12.7, 8.27)

# Creating the count plot
sns.countplot(x='foreign_worker_info_education', data=df,
              palette=sns.color_palette("Paired"),
              order=df['foreign_worker_info_education'].value_counts().index[:10])

# Iterating over elements in "foreign_worker_info_education" column and displaying counts above bars
for i, v in enumerate(df['foreign_worker_info_education'].value_counts().head(10)):
    ax.text(i, v, str(v), horizontalalignment='center', verticalalignment='bottom')

# Setting label titles
ax.set(xlabel='Education level', ylabel='Number of Visa applications')
plt.show()

# %%
#percentage of non null values

i = 0;
for col in df.columns:
    i = i+1;
    print (i-1,"Column: '{}'".format(col),"contains ", np.round(100*df[col].count()/len(df['case_status']),decimals=2),"% non-null values" )
# Out:
# 0 Column: 'add_these_pw_job_title_9089' contains  10.99 % non-null values
# 1 Column: 'agent_city' contains  56.92 % non-null values
# 2 Column: 'agent_firm_name' contains  55.74 % non-null values
# 3 Column: 'agent_state' contains  56.05 % non-null values
# 4 Column: 'application_type' contains  35.61 % non-null values
# 5 Column: 'case_received_date' contains  64.39 % non-null values
# 6 Column: 'case_status' contains  100.0 % non-null values
# 7 Column: 'class_of_admission' contains  94.08 % non-null values
# 8 Column: 'country_of_citizenship' contains  94.59 % non-null values
# 9 Column: 'country_of_citzenship' contains  5.4 % non-null values
# 10 Column: 'employer_address_1' contains  99.99 % non-null values
# 11 Column: 'employer_address_2' contains  33.7 % non-null values
# 12 Column: 'employer_city' contains  100.0 % non-null values
# 13 Column: 'employer_country' contains  64.37 % non-null values
# 14 Column: 'employer_decl_info_title' contains  64.37 % non-null values
# 15 Column: 'employer_name' contains  100.0 % non-null values
# 16 Column: 'employer_num_employees' contains  64.36 % non-null values
# 17 Column: 'employer_phone' contains  64.38 % non-null values
# 18 Column: 'employer_phone_ext' contains  6.32 % non-null values
# 19 Column: 'employer_postal_code' contains  99.99 % non-null values
# 20 Column: 'employer_state' contains  99.99 % non-null values
# 21 Column: 'employer_yr_estab' contains  64.35 % non-null values
# 22 Column: 'foreign_worker_info_alt_edu_experience' contains  23.66 % non-null values
# 23 Column: 'foreign_worker_info_birth_country' contains  23.67 % non-null values
# 24 Column: 'foreign_worker_info_city' contains  64.38 % non-null values
# 25 Column: 'foreign_worker_info_education' contains  59.69 % non-null values
# 26 Column: 'foreign_worker_info_education_other' contains  1.05 % non-null values
# 27 Column: 'foreign_worker_info_inst' contains  59.6 % non-null values
# 28 Column: 'foreign_worker_info_major' contains  59.35 % non-null values
# 29 Column: 'foreign_worker_info_postal_code' contains  22.95 % non-null values
# 30 Column: 'foreign_worker_info_rel_occup_exp' contains  23.67 % non-null values
# 31 Column: 'foreign_worker_info_req_experience' contains  23.67 % non-null values
# 32 Column: 'foreign_worker_info_state' contains  60.01 % non-null values
# 33 Column: 'foreign_worker_info_training_comp' contains  23.67 % non-null values
# 34 Column: 'foreign_worker_ownership_interest' contains  23.67 % non-null values
# 35 Column: 'foreign_worker_yr_rel_edu_completed' contains  22.3 % non-null values
# 36 Column: 'fw_info_alt_edu_experience' contains  40.72 % non-null values
# 37 Column: 'fw_info_birth_country' contains  40.71 % non-null values
# 38 Column: 'fw_info_education_other' contains  1.71 % non-null values
# 39 Column: 'fw_info_postal_code' contains  40.12 % non-null values
# 40 Column: 'fw_info_rel_occup_exp' contains  40.71 % non-null values
# 41 Column: 'fw_info_req_experience' contains  40.72 % non-null values
# 42 Column: 'fw_info_training_comp' contains  40.71 % non-null values
# 43 Column: 'fw_info_yr_rel_edu_completed' contains  37.35 % non-null values
# 44 Column: 'fw_ownership_interest' contains  40.72 % non-null values
# 45 Column: 'ji_foreign_worker_live_on_premises' contains  23.67 % non-null values
# 46 Column: 'ji_fw_live_on_premises' contains  40.72 % non-null values
# 47 Column: 'ji_live_in_dom_svc_contract' contains  0.65 % non-null values
# 48 Column: 'ji_live_in_domestic_service' contains  64.38 % non-null values
# 49 Column: 'ji_offered_to_sec_j_foreign_worker' contains  23.67 % non-null values
# 50 Column: 'ji_offered_to_sec_j_fw' contains  40.72 % non-null values
# 51 Column: 'job_info_alt_cmb_ed_oth_yrs' contains  19.07 % non-null values
# 52 Column: 'job_info_alt_combo_ed' contains  18.57 % non-null values
# 53 Column: 'job_info_alt_combo_ed_exp' contains  64.38 % non-null values
# 54 Column: 'job_info_alt_combo_ed_other' contains  2.52 % non-null values
# 55 Column: 'job_info_alt_field' contains  64.38 % non-null values
# 56 Column: 'job_info_alt_field_name' contains  25.34 % non-null values
# 57 Column: 'job_info_alt_occ' contains  40.15 % non-null values
# 58 Column: 'job_info_alt_occ_job_title' contains  39.96 % non-null values
# 59 Column: 'job_info_alt_occ_num_months' contains  39.9 % non-null values
# 60 Column: 'job_info_combo_occupation' contains  64.38 % non-null values
# 61 Column: 'job_info_education' contains  58.55 % non-null values
# 62 Column: 'job_info_education_other' contains  2.09 % non-null values
# 63 Column: 'job_info_experience' contains  64.38 % non-null values
# 64 Column: 'job_info_experience_num_months' contains  36.2 % non-null values
# 65 Column: 'job_info_foreign_ed' contains  64.32 % non-null values
# 66 Column: 'job_info_foreign_lang_req' contains  64.38 % non-null values
# 67 Column: 'job_info_job_req_normal' contains  64.38 % non-null values
# 68 Column: 'job_info_job_title' contains  64.37 % non-null values
# 69 Column: 'job_info_major' contains  57.54 % non-null values
# 70 Column: 'job_info_training' contains  64.38 % non-null values
# 71 Column: 'job_info_training_field' contains  1.2 % non-null values
# 72 Column: 'job_info_training_num_months' contains  1.28 % non-null values
# 73 Column: 'job_info_work_city' contains  99.97 % non-null values
# 74 Column: 'job_info_work_postal_code' contains  64.36 % non-null values
# 75 Column: 'job_info_work_state' contains  99.97 % non-null values
# 76 Column: 'naics_2007_us_code' contains  5.38 % non-null values
# 77 Column: 'naics_2007_us_title' contains  5.21 % non-null values
# 78 Column: 'naics_code' contains  23.61 % non-null values
# 79 Column: 'naics_title' contains  23.61 % non-null values
# 80 Column: 'naics_us_code' contains  40.63 % non-null values
# 81 Column: 'naics_us_code_2007' contains  30.11 % non-null values
# 82 Column: 'naics_us_title' contains  40.63 % non-null values
# 83 Column: 'naics_us_title_2007' contains  29.28 % non-null values
# 84 Column: 'orig_case_no' contains  0.08 % non-null values
# 85 Column: 'orig_file_date' contains  0.07 % non-null values
# 86 Column: 'preparer_info_emp_completed' contains  64.37 % non-null values
# 87 Column: 'preparer_info_title' contains  56.59 % non-null values
# 88 Column: 'pw_amount_9089' contains  99.38 % non-null values
# 89 Column: 'pw_determ_date' contains  64.3 % non-null values
# 90 Column: 'pw_expire_date' contains  64.28 % non-null values
# 91 Column: 'pw_job_title_908' contains  40.7 % non-null values
# 92 Column: 'pw_job_title_9089' contains  59.2 % non-null values
# 93 Column: 'pw_level_9089' contains  92.54 % non-null values
# 94 Column: 'pw_soc_code' contains  99.84 % non-null values
# 95 Column: 'pw_soc_title' contains  99.35 % non-null values
# 96 Column: 'pw_source_name_9089' contains  99.41 % non-null values
# 97 Column: 'pw_source_name_other_9089' contains  4.28 % non-null values
# 98 Column: 'pw_track_num' contains  63.87 % non-null values
# 99 Column: 'pw_unit_of_pay_9089' contains  99.58 % non-null values
# 100 Column: 'rec_info_barg_rep_notified' contains  23.65 % non-null values
# 101 Column: 'recr_info_barg_rep_notified' contains  40.71 % non-null values
# 102 Column: 'recr_info_coll_teach_comp_proc' contains  1.91 % non-null values
# 103 Column: 'recr_info_coll_univ_teacher' contains  64.38 % non-null values
# 104 Column: 'recr_info_employer_rec_payment' contains  64.38 % non-null values
# 105 Column: 'recr_info_first_ad_start' contains  62.71 % non-null values
# 106 Column: 'recr_info_job_fair_from' contains  0.48 % non-null values
# 107 Column: 'recr_info_job_fair_to' contains  0.48 % non-null values
# 108 Column: 'recr_info_on_campus_recr_from' contains  0.5 % non-null values
# 109 Column: 'recr_info_on_campus_recr_to' contains  0.49 % non-null values
# 110 Column: 'recr_info_pro_org_advert_from' contains  3.73 % non-null values
# 111 Column: 'recr_info_pro_org_advert_to' contains  3.73 % non-null values
# 112 Column: 'recr_info_prof_org_advert_from' contains  7.69 % non-null values
# 113 Column: 'recr_info_prof_org_advert_to' contains  7.69 % non-null values
# 114 Column: 'recr_info_professional_occ' contains  64.38 % non-null values
# 115 Column: 'recr_info_radio_tv_ad_from' contains  5.48 % non-null values
# 116 Column: 'recr_info_radio_tv_ad_to' contains  5.48 % non-null values
# 117 Column: 'recr_info_second_ad_start' contains  62.7 % non-null values
# 118 Column: 'recr_info_sunday_newspaper' contains  62.74 % non-null values
# 119 Column: 'recr_info_swa_job_order_end' contains  62.7 % non-null values
# 120 Column: 'recr_info_swa_job_order_start' contains  62.71 % non-null values
# 121 Column: 'refile' contains  30.41 % non-null values
# 122 Column: 'ri_1st_ad_newspaper_name' contains  62.72 % non-null values
# 123 Column: 'ri_2nd_ad_newspaper_name' contains  62.7 % non-null values
# 124 Column: 'ri_2nd_ad_newspaper_or_journal' contains  62.71 % non-null values
# 125 Column: 'ri_campus_placement_from' contains  8.08 % non-null values
# 126 Column: 'ri_campus_placement_to' contains  8.08 % non-null values
# 127 Column: 'ri_coll_tch_basic_process' contains  1.91 % non-null values
# 128 Column: 'ri_coll_teach_pro_jnl' contains  1.56 % non-null values
# 129 Column: 'ri_coll_teach_select_date' contains  1.56 % non-null values
# 130 Column: 'ri_employee_referral_prog_from' contains  18.62 % non-null values
# 131 Column: 'ri_employee_referral_prog_to' contains  18.62 % non-null values
# 132 Column: 'ri_employer_web_post_from' contains  37.03 % non-null values
# 133 Column: 'ri_employer_web_post_to' contains  37.02 % non-null values
# 134 Column: 'ri_job_search_website_from' contains  53.29 % non-null values
# 135 Column: 'ri_job_search_website_to' contains  53.28 % non-null values
# 136 Column: 'ri_layoff_in_past_six_months' contains  64.38 % non-null values
# 137 Column: 'ri_local_ethnic_paper_from' contains  32.66 % non-null values
# 138 Column: 'ri_local_ethnic_paper_to' contains  32.66 % non-null values
# 139 Column: 'ri_posted_notice_at_worksite' contains  64.36 % non-null values
# 140 Column: 'ri_pvt_employment_firm_from' contains  4.53 % non-null values
# 141 Column: 'ri_pvt_employment_firm_to' contains  4.52 % non-null values
# 142 Column: 'ri_us_workers_considered' contains  4.65 % non-null values
# 143 Column: 'schd_a_sheepherder' contains  64.38 % non-null values
# 144 Column: 'us_economic_sector' contains  33.94 % non-null values
# 145 Column: 'wage_offer_from_9089' contains  69.76 % non-null values
# 146 Column: 'wage_offer_to_9089' contains  19.87 % non-null values
# 147 Column: 'wage_offer_unit_of_pay_9089' contains  69.46 % non-null values
# 148 Column: 'wage_offered_from_9089' contains  30.21 % non-null values
# 149 Column: 'wage_offered_to_9089' contains  8.23 % non-null values
# 150 Column: 'wage_offered_unit_of_pay_9089' contains  18.73 % non-null values
# 151 Column: 'casenumber' contains  100.0 % non-null values
# 152 Column: 'year' contains  100.0 % non-null values
# 153 Column: 'month' contains  100.0 % non-null values
# 154 Column: 'day' contains  100.0 % non-null values

# %%
#keep the columns with non null values count > 33000

df = df.loc[:, df.count()>= 330000]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 356168 entries, 0 to 374353
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   case_status             356168 non-null  object
#  1   class_of_admission      335083 non-null  object
#  2   country_of_citizenship  336896 non-null  object
#  3   employer_address_1      356131 non-null  object
#  4   employer_city           356158 non-null  object
#  5   employer_name           356160 non-null  object
#  6   employer_postal_code    356135 non-null  object
#  7   employer_state          356131 non-null  object
#  8   job_info_work_city      356073 non-null  object
#  9   job_info_work_state     356072 non-null  object
#  10  pw_amount_9089          353965 non-null  object
#  11  pw_soc_code             355594 non-null  object
#  12  pw_soc_title            353847 non-null  object
#  13  pw_source_name_9089     354081 non-null  object
#  14  pw_unit_of_pay_9089     354687 non-null  object
#  15  casenumber              356168 non-null  object
#  16  year                    356168 non-null  int32
#  17  month                   356168 non-null  int32
#  18  day                     356168 non-null  int32
# dtypes: int32(3), object(16)
# memory usage: 50.3+ MB

# %%
df.case_status
# Out:
# 0         Certified
# 1            Denied
# 2         Certified
# 3         Certified
# 4         Certified
#             ...
# 374349    Certified
# 374350    Certified
# 374351    Certified
# 374352    Certified
# 374353    Certified
# Name: case_status, Length: 356168, dtype: object

# %%
df.loc[df['case_status'] == 'Certified', 'case_status'] =1
df.loc[df['case_status'] == 'Denied', 'case_status'] =0

# %%
df['case_status'].unique()
# Out:
# array([1, 0], dtype=object)

# %%
df['employer_state'].isnull().sum()
# Out:
# 37

# %%
df['employer_state'].mode()[0]
# Out:
# 'CALIFORNIA'

# %%
df['employer_state'] =df['employer_state'].fillna(df['employer_state'].mode()[0])

# %%
df['employer_state'].isnull().sum()
# Out:
# 0

# %%
df['employer_state']
# Out:
# 0         NY
# 1         NY
# 2         VA
# 3         NY
# 4         NY
#           ..
# 374349    KY
# 374350    OH
# 374351    CA
# 374352    NY
# 374353    NJ
# Name: employer_state, Length: 356168, dtype: object

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Dictionary for mapping state names to abbreviations
state_abbrevs = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
    'Northern Mariana Islands':'MP',
    'Palau': 'PW',
    'Puerto Rico': 'PR',
    'Virgin Islands': 'VI',
    'District of Columbia': 'DC'
}

# Reverse dictionary for abbreviation to state name mapping
abbrev_to_state = {v: k.upper() for k, v in state_abbrevs.items()}

# Clean and transform employer_state column in DataFrame
df['employer_state'] = df['employer_state'].fillna('').astype(str).str.strip().str.upper()

# Replace abbreviations with full state names
df['employer_state'] = df['employer_state'].replace(abbrev_to_state)

# %%
df['employer_state']
# Out:
# 0           NEW YORK
# 1           NEW YORK
# 2           VIRGINIA
# 3           NEW YORK
# 4           NEW YORK
#              ...
# 374349      KENTUCKY
# 374350          OHIO
# 374351    CALIFORNIA
# 374352      NEW YORK
# 374353    NEW JERSEY
# Name: employer_state, Length: 356168, dtype: object

# %%
df.pw_soc_code
# Out:
# 0         15-1031.00
# 1         47-4041.00
# 2         17-2051.00
# 3         43-4071.00
# 4         41-9031.00
#              ...
# 374349       15-1132
# 374350       15-1132
# 374351       15-1121
# 374352       15-1122
# 374353       13-1111
# Name: pw_soc_code, Length: 356168, dtype: object

# %%
df['pw_soc_code'] = df['pw_soc_code'].str.replace('.','')
df['pw_soc_code'] = df['pw_soc_code'].str.replace('-','')
df['pw_soc_code'] = df['pw_soc_code'].astype(str).str[0:6]
df['pw_soc_code'].value_counts()

#Finding "nan" values in "pw_soc_code" column and filling them with mode
df.loc[df['pw_soc_code'] == "nan",'pw_soc_code'] = df['pw_soc_code'].mode()[0]

#Finding "None" values in "pw_soc_code" column and filling them with mode
df.loc[df['pw_soc_code'] == "None",'pw_soc_code'] = df['pw_soc_code'].mode()[0]

#Changing type from string to int
df['pw_soc_code'] = df['pw_soc_code'].astype(int)
df['case_status'] = df['case_status'].astype(int)

# %%
df['case_status']
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 374349    1
# 374350    1
# 374351    1
# 374352    1
# 374353    1
# Name: case_status, Length: 356168, dtype: int32

# %%
#missing value treatment for other columns

#Replacing missing values with mode
df['class_of_admission']=df['class_of_admission'].fillna((df['class_of_admission'].mode()[0]))
df['country_of_citizenship']=df['country_of_citizenship'].fillna((df['country_of_citizenship'].mode()[0]))
df['employer_city']=df['employer_city'].fillna((df['employer_city'].mode()[0]))
df['employer_name']=df['employer_name'].fillna((df['employer_name'].mode()[0]))
df['employer_name']=df['employer_name'].astype(str).str.upper()
df['pw_source_name_9089']=df['pw_source_name_9089'].fillna((df['pw_source_name_9089'].mode()[0]))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 356168 entries, 0 to 374353
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   case_status             356168 non-null  int32
#  1   class_of_admission      356168 non-null  object
#  2   country_of_citizenship  356168 non-null  object
#  3   employer_address_1      356131 non-null  object
#  4   employer_city           356168 non-null  object
#  5   employer_name           356168 non-null  object
#  6   employer_postal_code    356135 non-null  object
#  7   employer_state          356168 non-null  object
#  8   job_info_work_city      356073 non-null  object
#  9   job_info_work_state     356072 non-null  object
#  10  pw_amount_9089          353965 non-null  object
#  11  pw_soc_code             356168 non-null  int32
#  12  pw_soc_title            353847 non-null  object
#  13  pw_source_name_9089     356168 non-null  object
#  14  pw_unit_of_pay_9089     354687 non-null  object
#  15  casenumber              356168 non-null  object
#  16  year                    356168 non-null  int32
#  17  month                   356168 non-null  int32
#  18  day                     356168 non-null  int32
# dtypes: int32(5), object(14)
# memory usage: 47.6+ MB

# %%
# Convert the column containing numerical values with commas to numeric format
df['pw_amount_9089'] = df['pw_amount_9089'].str.replace(',', '').astype(float)

# Now, you can replace null values in the numerical column with the median
median_pw_amount = df['pw_amount_9089'].median()
df['pw_amount_9089'].fillna(median_pw_amount, inplace=True)

# Verify that there are no more null values
print(df.isnull().sum())
# Out:
# case_status                  0
# class_of_admission           0
# country_of_citizenship       0
# employer_address_1          37
# employer_city                0
# employer_name                0
# employer_postal_code        33
# employer_state               0
# job_info_work_city          95
# job_info_work_state         96
# pw_amount_9089               0
# pw_soc_code                  0
# pw_soc_title              2321
# pw_source_name_9089          0
# pw_unit_of_pay_9089       1481
# casenumber                   0
# year                         0
# month                        0
# day                          0
# dtype: int64

# %%
#Indices of selected features for categorcal data to do encoding
chosen_attrs = [0,1,2,5,6,8,12,14,17]
df = df.iloc[:,chosen_attrs]

# %%
from sklearn.preprocessing import LabelEncoder
categorical_variables = {}

#Creating categories denoted by integers from column values
for col in df.columns:
    cat_var_name = "cat_"+ col
    cat_var_name = LabelEncoder()
    cat_var_name.fit(df[col])
    df[col] = cat_var_name.transform(df[col])
    categorical_variables[col] = cat_var_name

df.info()
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:174, in _unique_python(values, return_inverse, return_counts)
#     172 uniques_set, missing_values = _extract_missing(uniques_set)
# --> 174 uniques = sorted(uniques_set)
#     175 uniques.extend(missing_values.to_list())
#
# TypeError: '<' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                              Traceback (most recent call last)
# Cell In[234], line 8
#       6 cat_var_name = "cat_"+ col
#       7 cat_var_name = LabelEncoder()
# ----> 8 cat_var_name.fit(df[col])
#       9 df[col] = cat_var_name.transform(df[col])
#      10 categorical_variables[col] = cat_var_name
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:98, in LabelEncoder.fit(self, y)
#      85 """Fit label encoder.
#      86
#      87 Parameters
#    (...)
#      95     Fitted label encoder.
#      96 """
#      97 y = column_or_1d(y, warn=True)
# ---> 98 self.classes_ = _unique(y)
#      99 return self
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:42, in _unique(values, return_inverse, return_counts)
#      11 """Helper function to find unique values with support for python objects.
#      12
#      13 Uses pure python method for object dtype, and numpy method for
#    (...)
#      39     array. Only provided if `return_counts` is True.
#      40 """
#      41 if values.dtype == object:
# ---> 42     return _unique_python(
#      43         values, return_inverse=return_inverse, return_counts=return_counts
#      44     )
#      45 # numerical
#      46 return _unique_np(
#      47     values, return_inverse=return_inverse, return_counts=return_counts
#      48 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:179, in _unique_python(values, return_inverse, return_counts)
#     177 except TypeError:
#     178     types = sorted(t.__qualname__ for t in set(type(v) for v in values))
# --> 179     raise TypeError(
#     180         "Encoders require their input argument must be uniformly "
#     181         f"strings or numbers. Got {types}"
#     182     )
#     183 ret = (uniques,)
#     185 if return_inverse:
#
# TypeError: Encoders require their input argument must be uniformly strings or numbers. Got ['float', 'str']
